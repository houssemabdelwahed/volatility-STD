# %%
import pandas as pd
import yfinance as yf
import numpy as np
from datetime import datetime

# %%
stockstartdate='2020-01-01'
today=datetime.today().strftime('%Y-%m-%d')
today
# Out:
# '2022-03-07'

# %%
stock = yf.download("BTC-USD", start=stockstartdate, end=today, interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-12-31   7294.438965   7335.290039   7169.777832   7193.599121
# 2020-01-01   7194.892090   7254.330566   7174.944336   7200.174316
# 2020-01-02   7202.551270   7212.155273   6935.270020   6985.470215
# 2020-01-03   6984.428711   7413.715332   6914.996094   7344.884277
# 2020-01-04   7345.375488   7427.385742   7309.514160   7410.656738
# ...                  ...           ...           ...           ...
# 2022-03-02  44357.617188  45077.578125  43432.851562  43924.117188
# 2022-03-03  43925.195312  44021.578125  41914.750000  42451.789062
# 2022-03-04  42458.140625  42479.613281  38805.847656  39137.605469
# 2022-03-05  39148.449219  39566.335938  38777.035156  39400.585938
# 2022-03-06  39404.199219  39640.175781  38211.648438  38419.984375
#
#                Adj Close       Volume
# Date
# 2019-12-31   7193.599121  21167946112
# 2020-01-01   7200.174316  18565664997
# ...

# %%
stock['Log returns'] = np.log(stock['Close']/stock['Close'].shift())

# %%
stock
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-12-31   7294.438965   7335.290039   7169.777832   7193.599121
# 2020-01-01   7194.892090   7254.330566   7174.944336   7200.174316
# 2020-01-02   7202.551270   7212.155273   6935.270020   6985.470215
# 2020-01-03   6984.428711   7413.715332   6914.996094   7344.884277
# 2020-01-04   7345.375488   7427.385742   7309.514160   7410.656738
# ...                  ...           ...           ...           ...
# 2022-03-02  44357.617188  45077.578125  43432.851562  43924.117188
# 2022-03-03  43925.195312  44021.578125  41914.750000  42451.789062
# 2022-03-04  42458.140625  42479.613281  38805.847656  39137.605469
# 2022-03-05  39148.449219  39566.335938  38777.035156  39400.585938
# 2022-03-06  39404.199219  39640.175781  38211.648438  38419.984375
#
#                Adj Close       Volume  Log returns
# Date
# 2019-12-31   7193.599121  21167946112          NaN
# ...

# %%
stock['Log returns'].std()
# Out:
# 0.04072516689512172

# %%
stock['STD'] = stock['Log returns'].std()
stock
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-12-31   7294.438965   7335.290039   7169.777832   7193.599121
# 2020-01-01   7194.892090   7254.330566   7174.944336   7200.174316
# 2020-01-02   7202.551270   7212.155273   6935.270020   6985.470215
# 2020-01-03   6984.428711   7413.715332   6914.996094   7344.884277
# 2020-01-04   7345.375488   7427.385742   7309.514160   7410.656738
# ...                  ...           ...           ...           ...
# 2022-03-02  44357.617188  45077.578125  43432.851562  43924.117188
# 2022-03-03  43925.195312  44021.578125  41914.750000  42451.789062
# 2022-03-04  42458.140625  42479.613281  38805.847656  39137.605469
# 2022-03-05  39148.449219  39566.335938  38777.035156  39400.585938
# 2022-03-06  39404.199219  39640.175781  38211.648438  38419.984375
#
#                Adj Close       Volume  Log returns       STD
# Date
# 2019-12-31   7193.599121  21167946112          NaN  0.040725
# ...

# %%
volatility = stock['Log returns'].std()*365**.5
volatility
# Out:
# 0.7780532210600789

# %%
import matplotlib.pyplot as plt

# %%
str_vol = str(round(volatility, 4)*100)
fig, ax = plt.subplots()
stock['Log returns'].hist(ax=ax, bins=50, alpha=0.6, color='b')
ax.set_xlabel('Log return')
ax.set_ylabel('Freq of log return')
ax.set_title('BTC-USD volatility: ' + str_vol + '%')
# Out:
# Text(0.5, 1.0, 'BTC-USD volatility: 77.81%')
